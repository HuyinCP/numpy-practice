# %% [markdown]
# # Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot([-1, -1, -1, 5, 3, -5, 4, 5, 6, 6, 7])
plt.show()

# %%
sns.displot([14, 15, 28, 27, 32, 35], kind="kde")
plt.show()
